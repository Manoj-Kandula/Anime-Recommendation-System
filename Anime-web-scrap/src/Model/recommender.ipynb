# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Cleaning

# %%
data1= pd.read_csv('anime.csv')

# %%
data1.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
data1 = data1.sort_values(by='anime_id',ascending=True)

# %%
data1.head(20)
# Out:
#       anime_id                             name  \
# 22           1                     Cowboy Bebop
# 152          5  Cowboy Bebop: Tengoku no Tobira
# 214          6                           Trigun
# 2095         7               Witch Hunter Robin
# 3159         8           Beet the Vandel Buster
# 433         15                     Eyeshield 21
# 325         16             Hachimitsu to Clover
# 976         17       Hungry Heart: Wild Striker
# 263         18           Initial D Fourth Stage
# 38          19                          Monster
# 841         20                           Naruto
# 74          21                        One Piece
# 482         22                 Prince of Tennis
# 4536        23                 Ring ni Kakero 1
# 464         24                    School Rumble
# 1432        25                        Sunabouzu
# 906         26                       Texhnolyze
# 1805        27                    Trinity Blood
# ...

# %%
data1 = data1.reset_index(drop=True)

# %%
data1.head()
# Out:
#    anime_id                             name  \
# 0         1                     Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira
# 2         6                           Trigun
# 3         7               Witch Hunter Robin
# 4         8           Beet the Vandel Buster
#
#                                                genre   type episodes  rating  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space     TV       26    8.82
# 1              Action, Drama, Mystery, Sci-Fi, Space  Movie        1    8.40
# 2                             Action, Comedy, Sci-Fi     TV       26    8.32
# 3  Action, Drama, Magic, Mystery, Police, Superna...     TV       26    7.36
# 4          Adventure, Fantasy, Shounen, Supernatural     TV       52    7.06
#
#    members
# 0   486824
# 1   137636
# 2   283069
# 3    64905
# 4     9848

# %%
data1.describe()
# Out:
#            anime_id        rating       members
# count  12294.000000  12064.000000  1.229400e+04
# mean   14058.221653      6.473902  1.807134e+04
# std    11455.294701      1.026746  5.482068e+04
# min        1.000000      1.670000  5.000000e+00
# 25%     3484.250000      5.880000  2.250000e+02
# 50%    10260.500000      6.570000  1.550000e+03
# 75%    24794.500000      7.180000  9.437000e+03
# max    34527.000000     10.000000  1.013917e+06

# %%
data1.head()
# Out:
#    anime_id                             name  \
# 0         1                     Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira
# 2         6                           Trigun
# 3         7               Witch Hunter Robin
# 4         8           Beet the Vandel Buster
#
#                                                genre   type episodes  rating  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space     TV       26    8.82
# 1              Action, Drama, Mystery, Sci-Fi, Space  Movie        1    8.40
# 2                             Action, Comedy, Sci-Fi     TV       26    8.32
# 3  Action, Drama, Magic, Mystery, Police, Superna...     TV       26    7.36
# 4          Adventure, Fantasy, Shounen, Supernatural     TV       52    7.06
#
#    members
# 0   486824
# 1   137636
# 2   283069
# 3    64905
# 4     9848

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB

# %%
filtered_data = data1[data1['members'] > 10000]
filtered_data_with_nan = filtered_data[filtered_data.isnull().any(axis=1)]
filtered_data_with_nan.head()
# Out:
#       anime_id                                       name  \
# 3282      3786                        Evangelion: 3.0+1.0
# 5793      9488                                Cencoroll 2
# 8905     23279                           Gyakusatsu Kikan
# 9362     25537  Fate/stay night Movie: Heaven&#039;s Feel
# 9402     25777                Shingeki no Kyojin Season 2
#
#                                              genre   type episodes  rating  \
# 3282                         Action, Mecha, Sci-Fi  Movie        1     NaN
# 5793                                Action, Sci-Fi  Movie        1     NaN
# 8905                         Psychological, Sci-Fi  Movie        1     NaN
# 9362          Action, Fantasy, Magic, Supernatural  Movie        1     NaN
# 9402  Action, Drama, Fantasy, Shounen, Super Power     TV  Unknown     NaN
#
#       members
# 3282    66600
# 5793    15181
# 8905    12529
# 9362    53365
# 9402   170054

# %%
filtered_data_with_nan.head(44)
# Out:
#        anime_id                                               name  \
# 3282       3786                                Evangelion: 3.0+1.0
# 5793       9488                                        Cencoroll 2
# 8905      23279                                   Gyakusatsu Kikan
# 9362      25537          Fate/stay night Movie: Heaven&#039;s Feel
# 9402      25777                        Shingeki no Kyojin Season 2
# 10580     30455               Kantai Collection: KanColle Zoku-hen
# 10592     30484                                      Steins;Gate 0
# 10593     30485                                        ChäoS;Child
# 10657     30727                     Saenai Heroine no Sodatekata ♭
# 10659     30736                   Shingeki no Bahamut: Virgin Soul
# 10685     30778                                 Fairy Tail Movie 2
# 11073     31658                        Kuroko no Basket: Last Game
# 11127     31758                   Kizumonogatari III: Reiketsu-hen
# ...

# %%
filtered_data_with_nan.describe()
# Out:
#            anime_id  rating        members
# count     44.000000    1.00      44.000000
# mean   31152.659091    6.96   27756.181818
# std     5934.290780     NaN   28388.150878
# min     3786.000000    6.96   10067.000000
# 25%    31438.000000    6.96   12919.250000
# 50%    33027.000000    6.96   18018.000000
# 75%    33583.000000    6.96   24424.500000
# max    34451.000000    6.96  170054.000000

# %%
data_null = data1[data1.isnull().any(axis=1)]

# %%
data_null.head(10)
# Out:
#       anime_id                                    name  \
# 3282      3786                     Evangelion: 3.0+1.0
# 5793      9488                             Cencoroll 2
# 7795     17947  Mahou Shoujo Lyrical Nanoha Reflection
# 8055     19219                             Modern No.2
# 8303     20471                                Aoki Uru
# 8338     20715                                    Mint
# 8443     21305                          Trick or Alice
# 8565     21877                         High Score Girl
# 8903     23275                              Tsubu★Doll
# 8905     23279                        Gyakusatsu Kikan
#
#                                           genre   type episodes  rating  \
# 3282                      Action, Mecha, Sci-Fi  Movie        1     NaN
# 5793                             Action, Sci-Fi  Movie        1     NaN
# 7795  Action, Comedy, Drama, Magic, Super Power  Movie        1     NaN
# ...

# %%
data1.dropna(inplace=True)

# %%
data1.isnull().sum()
# Out:
# anime_id    0
# name        0
# genre       0
# type        0
# episodes    0
# rating      0
# members     0
# dtype: int64

# %%
data1['episodes'] = pd.to_numeric(data1['episodes'], errors='coerce')

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12017 entries, 0 to 12290
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12017 non-null  int64
#  1   name      12017 non-null  object
#  2   genre     12017 non-null  object
#  3   type      12017 non-null  object
#  4   episodes  11831 non-null  float64
#  5   rating    12017 non-null  float64
#  6   members   12017 non-null  int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 751.1+ KB

# %%
data1.isnull().sum()
# Out:
# anime_id      0
# name          0
# genre         0
# type          0
# episodes    186
# rating        0
# members       0
# dtype: int64

# %%
data1.dropna(inplace=True)

# %%
data1.head()
# Out:
#    anime_id                             name  \
# 0         1                     Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira
# 2         6                           Trigun
# 3         7               Witch Hunter Robin
# 4         8           Beet the Vandel Buster
#
#                                                genre   type  episodes  rating  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space     TV      26.0    8.82
# 1              Action, Drama, Mystery, Sci-Fi, Space  Movie       1.0    8.40
# 2                             Action, Comedy, Sci-Fi     TV      26.0    8.32
# 3  Action, Drama, Magic, Mystery, Police, Superna...     TV      26.0    7.36
# 4          Adventure, Fantasy, Shounen, Supernatural     TV      52.0    7.06
#
#    members
# 0   486824
# 1   137636
# 2   283069
# 3    64905
# 4     9848

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11831 entries, 0 to 12290
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  11831 non-null  int64
#  1   name      11831 non-null  object
#  2   genre     11831 non-null  object
#  3   type      11831 non-null  object
#  4   episodes  11831 non-null  float64
#  5   rating    11831 non-null  float64
#  6   members   11831 non-null  int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 739.4+ KB

# %%
data1['episodes'] = data1['episodes'].astype(int)

# %%
data1.isnull().sum()
# Out:
# anime_id    0
# name        0
# genre       0
# type        0
# episodes    0
# rating      0
# members     0
# dtype: int64

# %%
data1.isna().sum()
# Out:
# anime_id    0
# name        0
# genre       0
# type        0
# episodes    0
# rating      0
# members     0
# dtype: int64

# %%
missing_values = (data1['anime_id'].isna()) | (data1['anime_id'] == "") | (data1['anime_id'] == -1)
print(data1[missing_values])
# Out:
# Empty DataFrame
# Columns: [anime_id, name, genre, type, episodes, rating, members]
# Index: []

# %%
missing_values = (data1['episodes'].isna()) | (data1['episodes'] == "") | (data1['episodes'] == -1)
print(data1[missing_values])
# Out:
# Empty DataFrame
# Columns: [anime_id, name, genre, type, episodes, rating, members]
# Index: []

# %%
missing_values = (data1['rating'].isna()) | (data1['rating'] == "") | (data1['rating'] == -1)
print(data1[missing_values])
# Out:
# Empty DataFrame
# Columns: [anime_id, name, genre, type, episodes, rating, members]
# Index: []

# %%
missing_values = (data1['members'].isna()) | (data1['members'] == "") | (data1['members'] == -1)
print(data1[missing_values])
# Out:
# Empty DataFrame
# Columns: [anime_id, name, genre, type, episodes, rating, members]
# Index: []

# %%
missing_values = data1['type'] == "Unknown"
print(data1[missing_values])
# Out:
# Empty DataFrame
# Columns: [anime_id, name, genre, type, episodes, rating, members]
# Index: []

# %%
missing_values = data1['name'] == "Unknown"
print(data1[missing_values])
# Out:
# Empty DataFrame
# Columns: [anime_id, name, genre, type, episodes, rating, members]
# Index: []

# %%
missing_values = data1['genre'] == "Unknown"
print(data1[missing_values])
# Out:
# Empty DataFrame
# Columns: [anime_id, name, genre, type, episodes, rating, members]
# Index: []

# %%
print(data1['genre'].unique())
# Out:
# ['Action, Adventure, Comedy, Drama, Sci-Fi, Space'
#  'Action, Drama, Mystery, Sci-Fi, Space' 'Action, Comedy, Sci-Fi' ...
#  'Space' 'Fantasy, Horror, Seinen, Vampire'
#  'Action, Adventure, Fantasy, Game, Kids']

# %%
unique_genre = data1['genre'].value_counts()
print(unique_genre)
# Out:
# genre
# Hentai                                                             785
# Comedy                                                             500
# Music                                                              297
# Kids                                                               190
# Comedy, Slice of Life                                              166
#                                                                   ...
# Action, Adventure, Comedy, Ecchi, Sci-Fi, Shounen                    1
# Drama, Horror, Mystery, Police, Psychological, Seinen, Thriller      1
# Comedy, Drama, Josei, Romance                                        1
# Action, Drama, Magic, Mystery, Police, Supernatural                  1
# Action, Drama, Mystery, Sci-Fi, Space                                1
# Name: count, Length: 3217, dtype: int64

# %%
data1.head()
# Out:
#    anime_id                             name  \
# 0         1                     Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira
# 2         6                           Trigun
# 3         7               Witch Hunter Robin
# 4         8           Beet the Vandel Buster
#
#                                                genre   type  episodes  rating  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space     TV        26    8.82
# 1              Action, Drama, Mystery, Sci-Fi, Space  Movie         1    8.40
# 2                             Action, Comedy, Sci-Fi     TV        26    8.32
# 3  Action, Drama, Magic, Mystery, Police, Superna...     TV        26    7.36
# 4          Adventure, Fantasy, Shounen, Supernatural     TV        52    7.06
#
#    members
# 0   486824
# 1   137636
# 2   283069
# 3    64905
# 4     9848

# %%
print(data1.applymap(lambda x: x if isinstance(x, float) else None).isna().sum())
# Out:
# anime_id    11831
# name        11831
# genre       11831
# type        11831
# episodes    11831
# rating          0
# members     11831
# dtype: int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11831 entries, 0 to 12290
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  11831 non-null  int64
#  1   name      11831 non-null  object
#  2   genre     11831 non-null  object
#  3   type      11831 non-null  object
#  4   episodes  11831 non-null  int64
#  5   rating    11831 non-null  float64
#  6   members   11831 non-null  int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 739.4+ KB

# %%
data_temp = data1.copy()

# %%
data_temp.head()
# Out:
#    anime_id                             name  \
# 0         1                     Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira
# 2         6                           Trigun
# 3         7               Witch Hunter Robin
# 4         8           Beet the Vandel Buster
#
#                                                genre   type  episodes  rating  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space     TV        26    8.82
# 1              Action, Drama, Mystery, Sci-Fi, Space  Movie         1    8.40
# 2                             Action, Comedy, Sci-Fi     TV        26    8.32
# 3  Action, Drama, Magic, Mystery, Police, Superna...     TV        26    7.36
# 4          Adventure, Fantasy, Shounen, Supernatural     TV        52    7.06
#
#    members
# 0   486824
# 1   137636
# 2   283069
# 3    64905
# 4     9848

# %%
data_temp.sort_values(by='episodes',ascending=False,inplace=True)

# %%
data_temp[(data_temp['episodes']>1000) & (data_temp['episodes']<2000)]
# Out:
#        anime_id                                   name  \
# 6756      12393                             Oyako Club
# 2268       2471                        Doraemon (1979)
# 8929      23349                 Kirin Monoshiri Yakata
# 4540       6277     Manga Nippon Mukashibanashi (1976)
# 5287       8213                       Hoka Hoka Kazoku
# 11398     32448               Kirin Ashita no Calendar
# 8645      22221  Monoshiri Daigaku: Ashita no Calendar
# 11           21                              One Piece
# 6134      10241                  Sekai Monoshiri Ryoko
#
#                                                    genre type  episodes  \
# 6756                               Comedy, Slice of Life   TV      1818
# 2268   Adventure, Comedy, Fantasy, Kids, Sci-Fi, Shounen   TV      1787
# 8929                                                Kids   TV      1565
# 4540                                 Fantasy, Historical   TV      1471
# ...

# %%
data1[data1['name'] == 'One Piece']
# Out:
#     anime_id       name                                              genre  \
# 11        21  One Piece  Action, Adventure, Comedy, Drama, Fantasy, Sho...
#
#    type  episodes  rating  members
# 11   TV      1089    8.58   504862

# %% [markdown]
# # Modelling

# %%
from sklearn.preprocessing import LabelEncoder,MultiLabelBinarizer,StandardScaler
from sklearn.neighbors import NearestNeighbors

# %%
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MultiLabelBinarizer, MinMaxScaler
import numpy as np

def recommend_anime_by_name(anime_name):
    genre_weight=0.9, views_weight=0.1
    mlb = MultiLabelBinarizer()
    genre_matrix = mlb.fit_transform(data1['genre'])

    svd = TruncatedSVD(n_components=10)
    genre_svd = svd.fit_transform(genre_matrix)

    genre_similarity = cosine_similarity(genre_svd)

    scaler = MinMaxScaler()
    views_normalized = scaler.fit_transform(data1[['members']])

    anime_index = data1[data1['name'] == anime_name].index[0]

    genre_similarities = genre_similarity[anime_index]

    views_similarity = views_normalized.flatten()

    combined_similarity = genre_weight * genre_similarities + views_weight * views_similarity

    similar_indices = combined_similarity.argsort()[::-1][1:11]
    recommended_animes = data1.iloc[similar_indices]

    return recommended_animes['name']

anime_name = "Bleach"
recommended_animes = recommend_anime_by_name(anime_name, data1)
print(recommended_animes)
# Out:
# 5226       Highschool of the Dead
# 202                    Elfen Lied
# 7152                            K
# 4733    Dance in the Vampire Bund
# 17                  Trinity Blood
# 6491           Hellsing: The Dawn
# 6326       Blood-C: The Last Dark
# 708             Hellsing Ultimate
# 6244                      Blood-C
# 8308                     Noragami
# Name: name, dtype: object

# %%
le = LabelEncoder()
data1['type'] = le.fit_transform(data1['type'])
mlb = MultiLabelBinarizer()
genre = mlb.fit_transform(data1['genre'].str.split(','))
genre_df = pd.DataFrame(genre,columns=mlb.classes_)
data1_copy = data1.copy()
data1_copy = data1_copy.drop(columns=['genre'])
data2 = pd.concat([data1,genre_df],axis=1)
features = data2[['rating'] + list(genre_df)]
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)
print(features.isna().sum())
features.fillna(features.mean(), inplace=True)
# Out:
# rating          269
#  Adventure      269
#  Cars           269
#  Comedy         269
#  Dementia       269
#                ...
# Super Power     269
# Supernatural    269
# Thriller        269
# Vampire         269
# Yaoi            269
# Length: 83, dtype: int64

# %%
print(features.isna().sum())
# Out:
# rating          0
#  Adventure      0
#  Cars           0
#  Comedy         0
#  Dementia       0
#                ..
# Super Power     0
# Supernatural    0
# Thriller        0
# Vampire         0
# Yaoi            0
# Length: 83, dtype: int64

# %%
features_scaled = scaler.fit_transform(features)
print(features[features.isna().any(axis=1)])
# Out:
# Empty DataFrame
# Columns: [rating,  Adventure,  Cars,  Comedy,  Dementia,  Demons,  Drama,  Ecchi,  Fantasy,  Game,  Harem,  Hentai,  Historical,  Horror,  Josei,  Kids,  Magic,  Martial Arts,  Mecha,  Military,  Music,  Mystery,  Parody,  Police,  Psychological,  Romance,  Samurai,  School,  Sci-Fi,  Seinen,  Shoujo,  Shoujo Ai,  Shounen,  Shounen Ai,  Slice of Life,  Space,  Sports,  Super Power,  Supernatural,  Thriller,  Vampire,  Yaoi,  Yuri, Action, Adventure, Cars, Comedy, Dementia, Demons, Drama, Ecchi, Fantasy, Game, Harem, Hentai, Historical, Horror, Josei, Kids, Magic, Martial Arts, Mecha, Military, Music, Mystery, Parody, Police, Psychological, Romance, Samurai, School, Sci-Fi, Seinen, Shoujo, Shounen, Slice of Life, Space, Sports, Super Power, Supernatural, Thriller, Vampire, Yaoi]
# Index: []
#
# [0 rows x 83 columns]

# %%
knn = NearestNeighbors(n_neighbors=6, metric='euclidean')
knn.fit(features_scaled)
# Out:
# NearestNeighbors(metric='euclidean', n_neighbors=6)

# %%
def pred(anime_name = 'Cowboy Bebop'):
    anime_id = data1[data1['name'] == anime_name].iloc[0,0]
    anime_features = features_scaled[anime_id - 1].reshape(1, -1)
    distances, indices = knn.kneighbors(anime_features)
    similar_anime_ids = indices.flatten()[1:]
    similar_anime = data1.loc[similar_anime_ids, 'name']
    print(f"Recommended anime similar to {data1.loc[anime_id - 1, 'name']}:")
    print(similar_anime)
pred()
# Out:
# Recommended anime similar to Cowboy Bebop:
# 3442    Paul no Miracle Daisakusen
# 2006                         Waver
# 1346                         Youma
# 2490      Kaiketsu Jouki Tanteidan
# 374            Seikai no Senki III
# Name: name, dtype: object

# %%
pred('Cowboy Bebop')
# Out:
# Recommended anime similar to Cowboy Bebop:
# 3442    Paul no Miracle Daisakusen
# 2006                         Waver
# 1346                         Youma
# 2490      Kaiketsu Jouki Tanteidan
# 374            Seikai no Senki III
# Name: name, dtype: object

# %%
pred('One Piece')
# Out:
# Recommended anime similar to Neon Genesis Evangelion:
# 1843     Bakuen Campus Guardress
# 562                Yuugen Kaisha
# 3077                       Rayca
# 788                 .hack//Roots
# 1624    Little Monica Monogatari
# Name: name, dtype: object

# %%
pred('Naruto')
# Out:
# Recommended anime similar to Zipang:
# 7617                               Peeping Life Specials
# 6647                         Enshou Nihon Mukashibanashi
# 6201    Sono Hanabira ni Kuchizuke wo: Reo x Mai Diaries
# 4503                               Stretta The Animation
# 4504                                     Rita to Nantoka
# Name: name, dtype: object

# %%
pred('Berserk')
# Out:
# Recommended anime similar to Tenshi Kinryouku:
# 7047                    Kennel Tokorozawa
# 4732                           Durarara!!
# 1634      Dirty Pair: Bouryaku no 005-bin
# 3780    Chimera: Target I Datenshi Kourin
# 1371                      Imouto de Ikou!
# Name: name, dtype: object

# %%
data1 = data1.iloc[:features_scaled.shape[0], :]
features_scaled = features_scaled[:data1.shape[0], :]

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
pca = PCA(n_components=2)
features_2d = pca.fit_transform(features_scaled)
data1['PCA1'] = features_2d[:, 0]
data1['PCA2'] = features_2d[:, 1]

# %%
def plot_knn_recommendations(anime_id):
    anime_features = features_scaled[anime_id - 1].reshape(1, -1)
    distances, indices = knn.kneighbors(anime_features)
    similar_anime_ids = indices.flatten()
    plt.figure(figsize=(10, 6))
    plt.scatter(data1['PCA1'], data1['PCA2'], alpha=0.5, label="All Anime")
    plt.scatter(data1.loc[anime_id - 1, 'PCA1'], data1.loc[anime_id - 1, 'PCA2'], 
                color='red', s=100, edgecolors='black', label="Selected Anime")
    for idx in similar_anime_ids[1:]:
        plt.scatter(data1.loc[idx, 'PCA1'], data1.loc[idx, 'PCA2'], 
                    color='green', s=100, edgecolors='black')
    plt.xlabel("PCA 1")
    plt.ylabel("PCA 2")
    plt.title(f"Anime Recommendations for {data1.loc[anime_id - 1, 'name']}")
    plt.legend()
    plt.show()
plot_knn_recommendations(anime_id=21)

# %% [markdown]
# # Json

# %%
# import json
# columns = data1[['name','anime_id']]
# columns = columns.to_dict(orient='records')
# with open ('columns.json','w') as f:
#     json.dump(columns,f,indent=4)

# %%
# import pickle
# from sklearn.decomposition import TruncatedSVD
# from sklearn.preprocessing import MultiLabelBinarizer, MinMaxScaler
# mlb = MultiLabelBinarizer()
# genre_matrix = mlb.fit_transform(data1['genre'])
# svd = TruncatedSVD(n_components=10)
# genre_svd = svd.fit_transform(genre_matrix)
# scaler = MinMaxScaler()
# views_normalized = scaler.fit_transform(data1[['members']])
# with open('models.pkl', 'wb') as f:
#     pickle.dump({
#         'mlb': mlb,
#         'svd': svd,
#         'scaler': scaler,
#         'data': data1
#     }, f)
